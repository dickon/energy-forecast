# %%
from influxdb_client.client.write_api import SYNCHRONOUS
import influxdb_client, json, os.path, pprint, datetime, traceback
import time, pysolar
from dateutil.parser import isoparse
site = json.load(open(os.path.expanduser("~/src/powerwallextract/site.json")))

t0 = datetime.datetime.strptime('2023-01-01 00:00:00 Z', '%Y-%m-%d %H:%M:%S %z') # start of modelling period
t1 = datetime.datetime.strptime('2023-12-31 23:59:00 Z', '%Y-%m-%d %H:%M:%S %z') # end of modelling period
tnow = datetime.datetime.strptime(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S Z'), '%Y-%m-%d %H:%M:%S %z')

agile_incoming_cache = {}
URL = site['influx']['server']

client = influxdb_client.InfluxDBClient(url=URL, token=site['influx']['token'], org=site['influx']['org'])
write_api = client.write_api(write_options=SYNCHRONOUS)
query_api = client.query_api()
time_string_format = '%Y-%m-%dT%H:%M:%SZ'

def time_string(dt):
    return dt.strftime(time_string_format)

def do_query(query: str, bucket: str,  t0: datetime.datetime, t1: datetime.datetime, extra:str = "", verbose=False):
    import time
    fquery = f"""
            {extra}
            from(bucket: "{bucket}") |> range(start: {time_string(t0)}, stop: {time_string(t1)}) 
            {query}
""" 
    start = time.time()
    if verbose:
        print(fquery)
    resl = query_api.query(org=site['influx']['org'], query=fquery)
    end = time.time()
    delay = end - start
        
    if len(resl) == 0:
        if verbose:
            print('no results in', delay)
        return []
    if verbose:
        print('results in', delay)
    return resl[0]

def json_cache(filename, generate, max_age_days = 7):
    if os.path.exists(filename):
        mtime = os.stat(filename).st_mtime
        mtime_date = datetime.datetime.fromtimestamp(mtime)
        age = datetime.datetime.now() - mtime_date
        print('cache file', filename, 'age', age)
        if age.days < max_age_days:                
            try:
                with open(filename, 'r') as fp:
                    return json.load(fp)
            except:
                print(f'unable read {filename}; generating')
                traceback.print_exc()
    data = generate()
    with open(filename, 'w') as fp:
        json.dump(data, fp, indent=2)
    return data

# %% [markdown]
# # Model electricity demand
#
# Use 2023 actuals to work out the amount of electricity I use in each half hour window of the day.
# It turns out this is fairly stable over time. Maybe I could model winter lighting usage differently but
# with LED lights it's a fairly small component.
#
# Also, record the actual 2023 data so that we can use that for modelling where we have it. There are some
# gaps.
#
# This takes about 2 minutes on my server, so cache the results in JSON.
#
# We could make larger queries to Influx but the performance isn't a concern with the caching.

# %%
from time import time
import datetime
import matplotlib.pyplot as plt


def generate_mean_time_of_day():
    usage_actual = {}
    txover = datetime.datetime.strptime('2023-07-30 00:00:00 Z', '%Y-%m-%d %H:%M:%S %z')
    t = t0

    def query_usage(t):
        end_of_hh = t + datetime.timedelta(minutes=29)
        if (t.month == 8 and (t.day > 12 and t.day < 24) or t.day == 8 or t.day == 7) or (t.month == 7 and t.day in range(27,32)):
            return None, False
        if t < txover:
            res = do_query("""|> filter(fn: (r) => r["_measurement"] == "energy_usage")
            |> filter(fn: (r) => r["_field"] == "usage")
            |> filter(fn: (r) => r["account_name"] == "Primary Residence")
            |> filter(fn: (r) => r["detailed"] == "False")
            |> filter(fn: (r) => r["device_name"] == "Home-TotalUsage")
            |> filter(fn: (r) => r._value > 0.0)
            |> aggregateWindow(every: 30m, fn: mean, createEmpty: false)
            |> yield(name: "last")""", "vue", t, end_of_hh)
            abs = True
        else:
            res = do_query("""
            |> filter(fn: (r) => r["_measurement"] == "energy")
            |> filter(fn: (r) => r["_field"] == "energy_imported")
            |> filter(fn: (r) => r["meter"] == "load") |> last() """, "powerwall", t, end_of_hh)
            abs = False
        if res == []:
            return None,abs
        data = [(x["_stop"], x['_value']) for x in res]
        
        if (data[0][0] - t).seconds < 1800:
            return data[0][1], abs
        else:
            return None, abs


    time_of_day = {}
    base = None
    base_t = None

    while t < tnow:
        now, abs = query_usage(t)
        if abs:
            usage = now / 2 if now else 0
        else:
            if now:
                if base and t - base_t < datetime.timedelta(minutes=60):
                    usage = now - base 
                else:
                    usage = None
                base = now
                base_t = t
            else:#
                usage = None
        t = t + datetime.timedelta(minutes=30)
        if usage is not None and usage > 10:
            tday = f'{t.hour:02d}:{t.minute:02d}'
            time_of_day.setdefault(tday,list())
            time_of_day[tday].append(usage)
            usage_actual[t.isoformat()] = usage

    return  {"mean_time_of_day": [ (t, sum(x) / len(x)) for (t,x) in time_of_day.items()], "usage_actual": usage_actual}    

data = json_cache('kwh_use_time_of_day.json', generate_mean_time_of_day)
mean_time_of_day = data['mean_time_of_day']
usage_actual_text = data['usage_actual']
usage_actual = { datetime.datetime.fromisoformat(x[0]) : x[1] for x in usage_actual_text.items()}
values = [x for x in usage_actual.items() ]
plt.figure(figsize=(12,8))
plt.scatter([t for t, _ in values], [t.hour+t.minute/60 for t, _ in values], s=[v/100 for _, v in values], c=[v/100 for _, v in values])

# %% [markdown]
# # Model solar generation
#
# Pivot the solar generation we have on the position (altitude and azimuth) and work out mean power output of my solar panels of all the times we've seen output at that sun position.
#
# Then fill in results to the nearest point in solar position space.
#
# Takes about 3 minutes to run, so cache results.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from time import time
import datetime, pysolar

azi_resolution =3
alt_resolution =1

def get_solar_position_index(t):
    altitude = pysolar.solar.get_altitude(site['location']['latitude'], site['location']['longitude'], t+datetime.timedelta(minutes=15))
    azimuth = pysolar.solar.get_azimuth(site['location']['latitude'], site['location']['longitude'], t+datetime.timedelta(minutes=15))
    return alt_resolution*round(altitude/alt_resolution), azi_resolution*round(azimuth/azi_resolution)

txover = datetime.datetime.strptime(site['powerwall']['commission_date'], '%Y-%m-%d %H:%M:%S %z')

def query_solar(t):
    res = do_query("""
    |> filter(fn: (r) => r["_measurement"] == "power")
        |> filter(fn: (r) => r["_field"] == "instant_power")
        |> filter(fn: (r) => r["meter"] == "solar")
                   |> mean()
 """, 'powerwall', t, t+datetime.timedelta(minutes=30))
    data = [(x["_stop"], x['_value']) for x in res]
    if data:
        return data[0][1]

def generate_solar_model():
    bucket = "56new"


    solar_output_w = {}
    solar_pos_model = {}
    base = None
    t = tcommission = datetime.datetime.strptime(site['solar']['commission_date'], '%Y-%m-%d %H:%M:%S %z')
    #t = tnow - datetime.timedelta(hours=240)
    tbad0 = datetime.datetime.strptime('2023-08-11 00:00:00 Z', '%Y-%m-%d %H:%M:%S %z')
    tbad1 = datetime.datetime.strptime('2023-08-19 00:00:00 Z', '%Y-%m-%d %H:%M:%S %z')

    while t < tnow:
        usage = None
        if t > txover:
            usage = query_solar(t)
            
        else:
            resl = do_query("""
                |> filter(fn: (r) => r["_field"] == "usage")
                |> filter(fn: (r) => r["account_name"] == "Primary Residence")
                |> filter(fn: (r) => r["detailed"] == "True")
                |> filter(fn: (r) => r["device_name"] == "SolarEdge Inverter")
                |> mean() """,  'vue', t, t+datetime.timedelta(minutes=29))
            if resl:
                values = [-x['_value'] for x in resl]
                if values and values[0] > 10:
                    usage = values[0]
        if usage and (t < tbad0 or t>tbad1) and usage > 0:
            pos= get_solar_position_index(t)
            if pos[0] >= 0:
                solar_pos_model.setdefault(pos,list())
                solar_pos_model[pos].append(usage/2)
            
            solar_output_w[t.isoformat()] = usage/2

        t = t + datetime.timedelta(minutes=30)

    solar_model_table = dict()
    for pos, powl in solar_pos_model.items():
        solar_model_table[repr(pos)] = sum(powl) / len(powl)

    for azi in range(0, 360, azi_resolution):
        for alt in range(0, 70, alt_resolution):
            pos = (alt, azi)
            if pos not in solar_pos_model:
                mindist = None
                minv = None
                for altpos, powl in solar_pos_model.items():
                    dist = math.sqrt( (altpos[0] - pos[0])**2*10 + (altpos[1] - pos[1])**2  )
                    if mindist is None or dist < mindist:
                        minv = powl
                        mindist = dist
                solar_pos_model[pos] = minv
    
    # backfill the gaps
    t = tcommission
    while t < tnow:
        t_iso = t.isoformat()
        pos= get_solar_position_index(t)
        if t_iso not in solar_output_w:
            if pos[0] < 0:
                solar_output_w[t_iso] = 0
            else:
                values = solar_pos_model[pos]
                solar_output_w[t_iso] = sum(values) / len(values)

        t = t + datetime.timedelta(minutes=30)

    record =  {'table': solar_model_table, 'output': solar_output_w, 'model': [ (repr(pos), sum(solar_pos_model[pos]) / len(solar_pos_model[pos]), len(solar_pos_model[pos])) for pos in sorted(solar_pos_model.keys()) if pos[0] >=0] }
    pprint.pprint(record)
    return record

solar_model_record = json_cache('solar_model.json', generate_solar_model, max_age_days=7)
solar_output_w = { datetime.datetime.fromisoformat(t) : v for (t,v) in solar_model_record['output'].items() }
solar_model = solar_model_record['model']
solar_model_table = { eval(k):v for k,v in solar_model_record['table'].items()}


 

def plot_model(m):
    altitude = [ x[0][0] for x in m]
    azimuth = [ x[0][1] for x in m]
    pow = [ x[1]*2 for x in m]
    return plt.scatter(azimuth,altitude, [x/60 for x in pow], pow)



plt.figure(figsize=(12,8))

p = plot_model([(pos, v) for pos, v in solar_model_table.items()])
plt.xlabel('azimuth')
plt.ylabel('altitude')
plt.colorbar()

values = [x for x in solar_output_w.items() if x[1]>20 ]
plt.figure(figsize=(12,8))
plt.scatter([t for t, _ in values], [t.hour+t.minute/60 for t, _ in values], s=[v/100 for _, v in values], c=[v*2 for _, v in values])
plt.xlabel('date')
plt.ylabel('time of day')
plt.colorbar()

# %%
import matplotlib.pyplot as plt

def get_daily_gas_use():
    tback = t0
    res = do_query("""
  |> filter(fn: (r) => r["_measurement"] == "usage")
  |> filter(fn: (r) => r["_field"] == "usage")
  |> filter(fn: (r) => r["device_name"] == "utility meter")
  |> filter(fn: (r) => r["energy"] == "gas" )
  |> window(every: 1d)
  |> sum()
  |> duplicate(column: "_start", as: "_time")
  |> map(fn: (r) => ({ r with _time: date.add(d: 12h, to: r._time) }))
  |> window(every: inf)
  """, '56new', tback, t1, """import "date" """)
    res2 = do_query("""
  |> filter(fn: (r) => r["_measurement"] == "consumed")
  |> filter(fn: (r) => r["_field"] == "usage")
  |> filter(fn: (r) => r["device_name"] == "utility meter")
  |> filter(fn: (r) => r["energy"] == "gas")
    |> aggregateWindow(every: 24h, fn: mean,  createEmpty: false)
  |> map(fn: (r) => ({ r with _value: r._value * 1000.0  * 48.0 }))

  |> yield(name: "sum")""", '56new', tback, t1)
    out = {}
    wh_series = [
      
    ]
    t_series = []

    age_series = []
    date_series = []
    for row in list(res) + list(res2):
        temp = do_query("""
  |> filter(fn: (r) => r["_measurement"] == "sensor.openweathermap_condition" or r["_measurement"] == "weather.56_new_road")
  |> filter(fn: (r) => r["_field"] == "temperature_valid" or r["_field"] == "temperature")
  |> filter(fn: (r) => r["domain"] == "weather")
  |> filter(fn: (r) => r["entity_id"] == "56_new_road")
  |> aggregateWindow(every: 100h, fn: mean, createEmpty: false)
  //|> map(fn: (r) => ({ r with _value: math.mMax(x:0.0, y:18.0 - r._value ) }))
  |> yield(name: "mean")""", 'home-assistant', row['_time']-datetime.timedelta(hours=24), row['_time'], extra='import "math"')
        
        for outt in temp:
          pass
        if row['_value'] > 0:
          age_series.append( (tnow - row['_time']).days)
          t_series.append(outt['_value'])  
          wh_series.append(row['_value'])
        out[row['_time'].strftime('%Y-%m-%d')] = row['_value']
      

    plt.figure(figsize=(12,8))
    plt.scatter(wh_series, t_series,  c=age_series, cmap='coolwarm_r')
    plt.xlabel('Wh gas used')
    plt.ylabel('mean outside temperature')
    return out

gas_use = json_cache('gas.json', get_daily_gas_use)
len(gas_use.keys())

# %%
import datetime, pysolar, matplotlib, copy, random

latitude  = site['location']['latitude']
longitude = site['location']['longitude']
model_scale = 1
actual_scale = 8860/7632
battery_cost = 0 # take into account batter wear and tear if non-zero, in pounds
battery_lifetime_wh = 37.8e6 * 2
battery_size = 28000
maximum_charge_rate_watts = 10000
reserve_threshold = 0.25
battery_efficiency = 0.9
discharge_threshold = 0.48
discharge_price_floor = 0.27
discharge_rate_w = 10000
extra_verbose = False
verbose=True
battery_cost_per_wh = battery_cost / battery_lifetime_wh
print(f'battery cost per kwh=£{battery_cost_per_wh*1e3}')
def get_agile(t, outgoing=False):
    if t > tnow:
        t = t.replace(month=9, day = random.randint(1,28))
        
    v = agile_incoming_cache.get((t, outgoing))
    if v is not None:
        return v
    productq = 'r["product"] == "AGILE-OUTGOING-BB-23-02-28" or  r["product"] == "AGILE-OUTGOING-19-05-13"' if outgoing else 'r["product"] == "AGILE-FLEX-22-11-25" or r["product"] == "AGILE-BB-23-12-06"' 
    res = do_query(f"""
  |> filter(fn: (r) => r["_measurement"] == "unit_cost")
  |> filter(fn: (r) => r["_field"] == "price")
  |> filter(fn: (r) => {productq} )  |> last() """, 'tariffs', t, t+datetime.timedelta(minutes=29))
    v = [x['_value'] for x in res]
    if extra_verbose:
        print(t,v)
    r = v[0]
    agile_incoming_cache[(t, outgoing)] = r
    return r * site['tariffs']['agile']['scale']

usage_model = {t:u for (t,u) in mean_time_of_day}

# %%
def simulate_tariff(
    name='unknown', 
    grid_charge=False,
    grid_discharge=False,
    battery=False, solar=False, standing=0.4201, agile_charge=False,
    saving_sessions_discharge=False,
    winter_agile_import = False,
    gas_hot_water = False,
    costs = [
            {
                'start': 0,
                'end': 24,
                'import': 0.2793,
                'export': 0.15,
            },
        ], color='grey', verbose=False):
    if verbose:
        print('run simulation', name)
    kwh_days = []
    days =[]
    soc = battery_size if battery else 0

    cost = 0
    cost_series = []
    solar_prod = 0
    days = []
    halfhours = []
    soc_series = []
    solar_output_w_count = 0
    hh_count = 0
    soc_daily_lows = []
    day_costs = []
    t = t0
    for day in range(365):
        if verbose:
            print('day', day)
        kwh = 0
        day_cost = 0
        tday = t + datetime.timedelta(days=day)
        min_soc = soc
        soc_daily = []
        slots = [tday + datetime.timedelta(minutes=x*30) for x in range(48)]
        if agile_charge:
            agile_series = [(get_agile(x), x) for x in slots]
            lowest = sorted(agile_series)            
            agile_outgoing_series = [get_agile(x, True) for x in slots]
            highest_outgoing = list(reversed(sorted(agile_outgoing_series)))
            charge_slots = [x for x in lowest if x[0] < 0]
            if len(charge_slots) < 5:
                charge_slots = lowest[:5]
            print('charge slots', [ (x[0], x[1].strftime('%H:%M')) for x in charge_slots])
        else:
            charge_slots = []
        gas_hot_water_saving = 2200 if gas_hot_water else 0
        for hh in range(48):
            hh_count += 1
            t1 = tday + datetime.timedelta(minutes=hh*30)
            pos = get_solar_position_index(t1)
            if not solar:
                kwh_hh = 0 
                solar_real = False
            else:
                if t1 in solar_output_w:
                    kwh_hh = solar_output_w[t1] * actual_scale
                    solar_output_w_count += 1
                    solar_real = True
                else:
                    solar_real = False
                    kwh_hh = 0 if pos[0] <= 0  else  solar_model_table.get(pos, 0)
                    #print('estimated solar production', kwh_hh, 'at',t1, pos)
            if verbose:
                print(t, 'solar position', pos, 'solar production', kwh_hh)
            solar_prod += kwh_hh
            kwh +=  kwh_hh
            usage_hh = usage_actual.get(t1)
            usage_real = True
            if verbose and usage_hh:
                print(f'{t1} actual electrical usage {usage_hh}Wh')
            if usage_hh is None:
                usage_hh = usage_model[ t1.strftime('%H:%M')]
                usage_real = False
                if verbose:
                    print(f'{t1} modelled electrical usage {usage_hh}Wh')
            if t1.hour >= 2 and gas_hot_water_saving > 0:
                discount = min(gas_hot_water_saving, usage_hh-100)
                usage_hh -= discount
                if verbose:
                    print(f'gas hot water reduced usage at {t1} by  {discount}Wh to ${usage_hh}')
                assert usage_hh > 0 
            net_use =  usage_hh - kwh_hh # net wh energy requirement for the period
            if verbose:
                print(f'{t1} net electrical requirement {net_use}Wh')
            price_matches = [price for price in costs if t1.hour >= price['start'] and t1.hour < price['end']]
            assert len(price_matches) == 1, (price_matches, name, t1, costs)
            price = price_matches[0]
            if verbose:
                print(f'{t1} price structure {price}')
            import_cost = price['import']
            winter_override = (winter_agile_import and t1.month in [11,12,1,2,3])
            if import_cost == 'agile' or winter_override :
                import_cost = get_agile(t1) / 100
            if price['export'] == 'agile':
                export_payment = get_agile(t1,outgoing=True, )/100
                print('export',t1, 'is',export_payment )
            else:
                export_payment = price['export']
                if winter_override:
                    export_payment = 0.15
            if hh == 0:
                gas_kwh_day = gas_use.get(tday.strftime('%Y-%m-%d'), 0)/1000 + (10 if gas_hot_water else 0)
                gas_cost = site['tariffs']['gas']['standing_charge'] + gas_kwh_day*site['tariffs']['gas']['kwh_cost']
                if verbose:
                    print(f'{t1} gas use {gas_kwh_day}kWh, cost £${gas_cost:.2f}')
            else:
                gas_cost = 0
            hh_cost =  (standing + gas_cost) if hh == 0 else 0
            grid_flow = 0
            soc_delta = 0
            if verbose:
                print(f'{t1} net use {net_use}Wh')
            if net_use > 0:
                # we do need energy
                bat_reserve_limit = battery_size * reserve_threshold
                charge_add = min(net_use, soc-bat_reserve_limit, maximum_charge_rate_watts/2) if battery else 0
                grid_flow = net_use - charge_add
                soc_delta -= charge_add
                if verbose:
                    print(f'{t1} taking ${grid_flow}Wh from grid')
                hh_cost += import_cost * grid_flow/1000
            else:
                # we have spare energy
                if kwh_hh > 0:
                    charge_delta = min(-net_use, (battery_size - soc)/battery_efficiency) if battery else 0
                    soc_delta_charge = min(maximum_charge_rate_watts/2 - soc_delta, charge_delta * battery_efficiency)
                    print('charge', charge_delta, 'soc delta', soc_delta_charge, 'to deal with', net_use, )
                    soc_delta += soc_delta_charge
                    assert soc + soc_delta <= battery_size
                    export_kwh =  (- net_use - charge_delta) /1000
                else:
                    export_kwh = 0
                export_kwh = max(export_kwh, 0)
                grid_flow = -export_kwh*1000
                assert export_kwh >= 0
                hh_cost -= export_kwh * export_payment
            if agile_charge:                    
                grid_charge_now = t1 in [x[1] for x in charge_slots] and (soc > battery_size * 0.5 and import_cost > 0.1)
            else:
                grid_charge_now = t1.hour >= 2 and t1.hour < 5 and grid_charge and battery

            if grid_charge_now:
                grid_flow = min((battery_size - soc)/battery_efficiency, maximum_charge_rate_watts/2) - soc_delta
                hh_cost += import_cost * grid_flow / 1000
                add = grid_flow * battery_efficiency
                if verbose:
                    print('grid charge', grid_flow, 'add', add, 'soc delta was', soc_delta, 'now', soc_delta + add)
                soc_delta +=add
            export_payment_bonus = 0
            if grid_discharge or saving_sessions_discharge:
                if saving_sessions_discharge and t1.month in [12,1,2]:
                    #print('eval', t1.month, t1.day, t1.hour, t1.minute)
                    go = t1.month in [12, 1, 2] and t1.day in [7, 14, 21] and (t1.hour == 17 or (t1.hour==18 and t1.minute < 30))
                    export_payment_bonus = 4.2                  
                elif grid_discharge and price['export'] == 'agile':
                    go = export_payment >= highest_outgoing[6]/100 and export_payment > 0.25
                elif grid_discharge:
                    go = export_payment >= discharge_price_floor 
                if go: 
                    print('grid discharge available at', t, 'soc', soc)
                    if soc >= discharge_threshold * battery_size:
                        limit = battery_size * discharge_threshold
                        dump_amount = max(0, min((soc+soc_delta)-limit, discharge_rate_w/2))
                        print('dumping', dump_amount)
                        soc_delta -= dump_amount
                        payment = (dump_amount/1000) * (export_payment + export_payment_bonus)
                        hh_cost -= payment
                        if verbose:
                            print('t', t, 'grid dump at SOC', soc, 'of', dump_amount, 'payment', payment)
            # if import_cost < 0:
            #     hh_cost += import_cost * 4 # run some heaters
            battery_wear_cost = battery_cost_per_wh * -min(0, soc_delta)
            hh_cost += battery_wear_cost
            cost += hh_cost
            day_cost += hh_cost

            soc_daily.append(soc)
            soc_series.append(soc)
            halfhours.append(t1)
            
            new_soc = min(battery_size, soc + soc_delta)
            if verbose:
                print(f'{name} {t1} sun {pos}, solar prod {kwh_hh/1000:.3f}kWh{"*" if usage_real else "?"}, '+
                      f'usage {usage_hh/1000:.03f}{"*" if usage_real else "?"} net_use_house {net_use/1000:.03f} '+
                      f'grid flow {grid_flow/1000:.3f}kWh in@£{import_cost} ex@£{export_payment} '+
                      f'battery flow {soc_delta/1000:.3f}kWh -> {new_soc/1000:.3f}kWh min_bat '+
                      f'{min_soc/1000:.3f}kWh battery_wear=£{battery_wear_cost:0.02f} hh=£{hh_cost:0.02f} total £{cost:0.02f}')
            
            assert new_soc < battery_size*1.01, (new_soc, battery_size)

            soc = min(battery_size, soc)
            min_soc = min(soc, min_soc)
            soc = min(battery_size, new_soc)
            assert soc <= battery_size
            assert soc >= 0
        soc_daily_lows.append(100.0*min(soc_daily)/battery_size)
        days.append(tday)
        kwh_days.append(kwh)
        cost_series.append(cost)
        day_costs.append(day_cost)
    prev = 0
    month_cost = [0]*12
    months = []
    for cost, day in zip(day_costs, days):
        if day.day == 14:
            months.append(day)
        month_cost[day.month-1] += cost
    month_cost = month_cost[:len(months)]
    assert len(months) == len(month_cost), (len(months), len(month_cost), months, month_cost)

    return { 
        'month_cost': month_cost,
        'annual cost': cost_series[-1],
        'name':name,
        'soc_daily_lows': soc_daily_lows,
        'color':color,
        'kwh_days': kwh_days,
        'cost_series': cost_series,
        'days': days,
        'months': months
    }
old_results = simulate_tariff(name='flexible no solar no batteries',  gas_hot_water=True, verbose=False)
old_results

# %%
old_results = simulate_tariff(name='flexible no solar no batteries',  gas_hot_water=True, verbose=True)
old_results

# %%
discharge_results = simulate_tariff(name='discharge flux',         
        costs= site['tariffs']['flux']['kwh_costs'],
        grid_charge = True, grid_discharge=True,
        battery = True, solar=True,
        color=  'yellow', verbose=True,
        saving_sessions_discharge=True)
discharge_results

# %%
current_results = simulate_tariff(name='flux',         
        costs= site['tariffs']['flux']['kwh_costs'],
        grid_charge = True,
        battery = True, solar=True,
        color=  'green', verbose=False,
        saving_sessions_discharge=True)
current_results

# %%
winter_agile_result = simulate_tariff(name='winter agile',         
        costs= site['tariffs']['flux']['kwh_costs'],
        winter_agile_import=True,
        grid_charge = True,
        agile_charge=True,
        battery = True, solar=True,
        color=  'blue', verbose=True,
        saving_sessions_discharge=True)
winter_agile_result
# Out:
# charge slots [(12.359025, '01:30'), (12.822075, '02:00'), (13.671, '00:00'), (13.8915, '00:30'), (13.8915, '02:30')]
# 2023-01-01 00:00:00+00:00 solar position (-15, 3) solar production 0.0
# 2023-07-04 00:00:00+00:00 actual electrical usage 181.6494050464411Wh
# 2023-07-04 00:00:00+00:00 net electrical requirement 181.6494050464411Wh
# 2023-07-04 00:00:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 00:00:00+00:00 gas use 0.0kWh, cost £$0.27
# 2023-07-04 00:00:00+00:00 net use 181.6494050464411Wh
# 2023-07-04 00:00:00+00:00 taking $0.0Wh from grid
# grid charge 4782.038466451036 add 4303.834619805933 soc delta was -181.6494050464411 now 4122.185214759492
# winter agile 2023-07-04 00:00:00+00:00 sun (-15, 3), solar prod 0.000kWh*, usage 0.182* net_use_house 0.182 grid flow 4.782kWh in@£0.2922 ex@£0.1822 battery flow 4.122kWh -> 27.982kWh min_bat 23.860kWh battery_wear=£0.00 hh=£2.09 total £754.54
# 2023-01-01 00:00:00+00:00 solar position (-15, 9) solar production 0.0
# 2023-07-04 00:30:00+00:00 actual electrical usage 181.681682513226Wh
# 2023-07-04 00:30:00+00:00 net electrical requirement 181.681682513226Wh
# 2023-07-04 00:30:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 00:30:00+00:00 net use 181.681682513226Wh
# 2023-07-04 00:30:00+00:00 taking $0.0Wh from grid
# grid charge 201.86494974060892 add 181.67845476654804 soc delta was -181.681682513226 now -0.00322774667796466
# winter agile 2023-07-04 00:30:00+00:00 sun (-15, 9), solar prod 0.000kWh*, usage 0.182* net_use_house 0.182 grid flow 0.202kWh in@£0.2922 ex@£0.1822 battery flow -0.000kWh -> 27.982kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.06 total £754.60
# 2023-01-01 00:00:00+00:00 solar position (-14, 18) solar production 0.0
# 2023-07-04 01:00:00+00:00 actual electrical usage 168.56113874912265Wh
# 2023-07-04 01:00:00+00:00 net electrical requirement 168.56113874912265Wh
# 2023-07-04 01:00:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 01:00:00+00:00 net use 168.56113874912265Wh
# 2023-07-04 01:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 01:00:00+00:00 sun (-14, 18), solar prod 0.000kWh*, usage 0.169* net_use_house 0.169 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.169kWh -> 27.813kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.60
# 2023-01-01 00:00:00+00:00 solar position (-12, 24) solar production 0.0
# 2023-07-04 01:30:00+00:00 actual electrical usage 172.995501366977Wh
# 2023-07-04 01:30:00+00:00 net electrical requirement 172.995501366977Wh
# 2023-07-04 01:30:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 01:30:00+00:00 net use 172.995501366977Wh
# 2023-07-04 01:30:00+00:00 taking $0.0Wh from grid
# grid charge 380.47250914524955 add 342.4252582307246 soc delta was -172.995501366977 now 169.42975686374757
# winter agile 2023-07-04 01:30:00+00:00 sun (-12, 24), solar prod 0.000kWh*, usage 0.173* net_use_house 0.173 grid flow 0.380kWh in@£0.2922 ex@£0.1822 battery flow 0.169kWh -> 27.983kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.11 total £754.71
# 2023-01-01 00:00:00+00:00 solar position (-10, 30) solar production 0.0
# 2023-07-04 02:00:00+00:00 actual electrical usage 179.03385118379933Wh
# 2023-07-04 02:00:00+00:00 net electrical requirement 179.03385118379933Wh
# 2023-07-04 02:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 02:00:00+00:00 net use 179.03385118379933Wh
# 2023-07-04 02:00:00+00:00 taking $0.0Wh from grid
# grid charge 198.25557355790687 add 178.43001620211618 soc delta was -179.03385118379933 now -0.6038349816831499
# winter agile 2023-07-04 02:00:00+00:00 sun (-10, 30), solar prod 0.000kWh*, usage 0.179* net_use_house 0.179 grid flow 0.198kWh in@£0.1753 ex@£0.0653 battery flow -0.001kWh -> 27.982kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.03 total £754.74
# 2023-01-01 00:00:00+00:00 solar position (-7, 36) solar production 0.0
# 2023-07-04 02:30:00+00:00 actual electrical usage 174.4112221838414Wh
# 2023-07-04 02:30:00+00:00 net electrical requirement 174.4112221838414Wh
# 2023-07-04 02:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 02:30:00+00:00 net use 174.4112221838414Wh
# 2023-07-04 02:30:00+00:00 taking $0.0Wh from grid
# grid charge 194.30387231537614 add 174.87348508383852 soc delta was -174.4112221838414 now 0.4622628999971141
# winter agile 2023-07-04 02:30:00+00:00 sun (-7, 36), solar prod 0.000kWh*, usage 0.174* net_use_house 0.174 grid flow 0.194kWh in@£0.1753 ex@£0.0653 battery flow 0.000kWh -> 27.983kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.03 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (-5, 42) solar production 0.0
# 2023-07-04 03:00:00+00:00 actual electrical usage 156.35325064587448Wh
# 2023-07-04 03:00:00+00:00 net electrical requirement 156.35325064587448Wh
# 2023-07-04 03:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 03:00:00+00:00 net use 156.35325064587448Wh
# 2023-07-04 03:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 03:00:00+00:00 sun (-5, 42), solar prod 0.000kWh*, usage 0.156* net_use_house 0.156 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.156kWh -> 27.826kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (-1, 48) solar production 0.0
# 2023-07-04 03:30:00+00:00 actual electrical usage 173.89897391682578Wh
# 2023-07-04 03:30:00+00:00 net electrical requirement 173.89897391682578Wh
# 2023-07-04 03:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 03:30:00+00:00 net use 173.89897391682578Wh
# 2023-07-04 03:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 03:30:00+00:00 sun (-1, 48), solar prod 0.000kWh*, usage 0.174* net_use_house 0.174 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.174kWh -> 27.652kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (3, 54) solar production 23.64741520038856
# 2023-07-04 04:00:00+00:00 actual electrical usage 184.9291776974996Wh
# 2023-07-04 04:00:00+00:00 net electrical requirement 161.28176249711103Wh
# 2023-07-04 04:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 04:00:00+00:00 net use 161.28176249711103Wh
# 2023-07-04 04:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 04:00:00+00:00 sun (3, 54), solar prod 0.024kWh*, usage 0.185* net_use_house 0.161 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.161kWh -> 27.491kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (6, 60) solar production 36.1419543537043
# 2023-07-04 04:30:00+00:00 actual electrical usage 820.7795291257263Wh
# 2023-07-04 04:30:00+00:00 net electrical requirement 784.637574772022Wh
# 2023-07-04 04:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-04 04:30:00+00:00 net use 784.637574772022Wh
# 2023-07-04 04:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 04:30:00+00:00 sun (6, 60), solar prod 0.036kWh*, usage 0.821* net_use_house 0.785 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.785kWh -> 26.706kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (11, 66) solar production 117.76583961308809
# 2023-07-04 05:00:00+00:00 actual electrical usage 1612.1065064791978Wh
# 2023-07-04 05:00:00+00:00 net electrical requirement 1494.3406668661098Wh
# 2023-07-04 05:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 05:00:00+00:00 net use 1494.3406668661098Wh
# 2023-07-04 05:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 05:00:00+00:00 sun (11, 66), solar prod 0.118kWh*, usage 1.612* net_use_house 1.494 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -1.494kWh -> 25.212kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (15, 72) solar production 311.34465096142156
# 2023-07-04 05:30:00+00:00 actual electrical usage 559.3763510800543Wh
# 2023-07-04 05:30:00+00:00 net electrical requirement 248.03170011863273Wh
# 2023-07-04 05:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 05:30:00+00:00 net use 248.03170011863273Wh
# 2023-07-04 05:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 05:30:00+00:00 sun (15, 72), solar prod 0.311kWh*, usage 0.559* net_use_house 0.248 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.248kWh -> 24.964kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (19, 78) solar production 525.9954143981394
# 2023-07-04 06:00:00+00:00 actual electrical usage 171.0697062081304Wh
# 2023-07-04 06:00:00+00:00 net electrical requirement -354.92570819000895Wh
# 2023-07-04 06:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 06:00:00+00:00 net use -354.92570819000895Wh
# charge 354.92570819000895 soc delta 319.43313737100806 to deal with -354.92570819000895
# winter agile 2023-07-04 06:00:00+00:00 sun (19, 78), solar prod 0.526kWh*, usage 0.171* net_use_house -0.355 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.319kWh -> 25.283kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (24, 84) solar production 640.2962315062385
# 2023-07-04 06:30:00+00:00 actual electrical usage 163.02118259298388Wh
# 2023-07-04 06:30:00+00:00 net electrical requirement -477.27504891325464Wh
# 2023-07-04 06:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 06:30:00+00:00 net use -477.27504891325464Wh
# charge 477.27504891325464 soc delta 429.5475440219292 to deal with -477.27504891325464
# winter agile 2023-07-04 06:30:00+00:00 sun (24, 84), solar prod 0.640kWh*, usage 0.163* net_use_house -0.477 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.430kWh -> 25.713kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (29, 90) solar production 539.5950315451979
# 2023-07-04 07:00:00+00:00 actual electrical usage 189.52547107564988Wh
# 2023-07-04 07:00:00+00:00 net electrical requirement -350.06956046954804Wh
# 2023-07-04 07:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 07:00:00+00:00 net use -350.06956046954804Wh
# charge 350.06956046954804 soc delta 315.06260442259327 to deal with -350.06956046954804
# winter agile 2023-07-04 07:00:00+00:00 sun (29, 90), solar prod 0.540kWh*, usage 0.190* net_use_house -0.350 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.315kWh -> 26.028kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (33, 93) solar production 1016.6196042674919
# 2023-07-04 07:30:00+00:00 actual electrical usage 190.61448283195497Wh
# 2023-07-04 07:30:00+00:00 net electrical requirement -826.0051214355369Wh
# 2023-07-04 07:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 07:30:00+00:00 net use -826.0051214355369Wh
# charge 826.0051214355369 soc delta 743.4046092919832 to deal with -826.0051214355369
# winter agile 2023-07-04 07:30:00+00:00 sun (33, 93), solar prod 1.017kWh*, usage 0.191* net_use_house -0.826 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.743kWh -> 26.771kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (38, 102) solar production 1008.67556456069
# 2023-07-04 08:00:00+00:00 actual electrical usage 179.70078028536392Wh
# 2023-07-04 08:00:00+00:00 net electrical requirement -828.9747842753261Wh
# 2023-07-04 08:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 08:00:00+00:00 net use -828.9747842753261Wh
# charge 828.9747842753261 soc delta 746.0773058477935 to deal with -828.9747842753261
# winter agile 2023-07-04 08:00:00+00:00 sun (38, 102), solar prod 1.009kWh*, usage 0.180* net_use_house -0.829 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.746kWh -> 27.518kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £754.78
# 2023-01-01 00:00:00+00:00 solar position (42, 108) solar production 1313.9785305005637
# 2023-07-04 08:30:00+00:00 actual electrical usage 257.0562774658203Wh
# 2023-07-04 08:30:00+00:00 net electrical requirement -1056.9222530347433Wh
# 2023-07-04 08:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 08:30:00+00:00 net use -1056.9222530347433Wh
# charge 536.0665000885032 soc delta 482.4598500796529 to deal with -1056.9222530347433
# winter agile 2023-07-04 08:30:00+00:00 sun (42, 108), solar prod 1.314kWh*, usage 0.257* net_use_house -1.057 grid flow -0.521kWh in@£0.2922 ex@£0.1822 battery flow 0.482kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.09 total £754.68
# 2023-01-01 00:00:00+00:00 solar position (47, 114) solar production 1524.6724687645833
# 2023-07-04 09:00:00+00:00 actual electrical usage 269.04390963850346Wh
# 2023-07-04 09:00:00+00:00 net electrical requirement -1255.6285591260798Wh
# 2023-07-04 09:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 09:00:00+00:00 net use -1255.6285591260798Wh
# charge 0.0 soc delta 0.0 to deal with -1255.6285591260798
# winter agile 2023-07-04 09:00:00+00:00 sun (47, 114), solar prod 1.525kWh*, usage 0.269* net_use_house -1.256 grid flow -1.256kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.23 total £754.45
# 2023-01-01 00:00:00+00:00 solar position (51, 123) solar production 1234.0988748981026
# 2023-07-04 09:30:00+00:00 actual electrical usage 265.2134913580758Wh
# 2023-07-04 09:30:00+00:00 net electrical requirement -968.8853835400269Wh
# 2023-07-04 09:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 09:30:00+00:00 net use -968.8853835400269Wh
# charge 0.0 soc delta 0.0 to deal with -968.8853835400269
# winter agile 2023-07-04 09:30:00+00:00 sun (51, 123), solar prod 1.234kWh*, usage 0.265* net_use_house -0.969 grid flow -0.969kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.18 total £754.28
# 2023-01-01 00:00:00+00:00 solar position (54, 132) solar production 865.6680847106718
# 2023-07-04 10:00:00+00:00 actual electrical usage 256.8935402354975Wh
# 2023-07-04 10:00:00+00:00 net electrical requirement -608.7745444751743Wh
# 2023-07-04 10:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 10:00:00+00:00 net use -608.7745444751743Wh
# charge 0.0 soc delta 0.0 to deal with -608.7745444751743
# winter agile 2023-07-04 10:00:00+00:00 sun (54, 132), solar prod 0.866kWh*, usage 0.257* net_use_house -0.609 grid flow -0.609kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.11 total £754.17
# 2023-01-01 00:00:00+00:00 solar position (57, 144) solar production 2258.354123919518
# 2023-07-04 10:30:00+00:00 actual electrical usage 277.58510766741875Wh
# 2023-07-04 10:30:00+00:00 net electrical requirement -1980.7690162520992Wh
# 2023-07-04 10:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 10:30:00+00:00 net use -1980.7690162520992Wh
# charge 0.0 soc delta 0.0 to deal with -1980.7690162520992
# winter agile 2023-07-04 10:30:00+00:00 sun (57, 144), solar prod 2.258kWh*, usage 0.278* net_use_house -1.981 grid flow -1.981kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.36 total £753.81
# 2023-01-01 00:00:00+00:00 solar position (59, 156) solar production 2878.1685342819264
# 2023-07-04 11:00:00+00:00 actual electrical usage 338.30535446693165Wh
# 2023-07-04 11:00:00+00:00 net electrical requirement -2539.863179814995Wh
# 2023-07-04 11:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 11:00:00+00:00 net use -2539.863179814995Wh
# charge 0.0 soc delta 0.0 to deal with -2539.863179814995
# winter agile 2023-07-04 11:00:00+00:00 sun (59, 156), solar prod 2.878kWh*, usage 0.338* net_use_house -2.540 grid flow -2.540kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.46 total £753.34
# 2023-01-01 00:00:00+00:00 solar position (61, 171) solar production 1395.3663724635796
# 2023-07-04 11:30:00+00:00 actual electrical usage 252.5502116612025Wh
# 2023-07-04 11:30:00+00:00 net electrical requirement -1142.8161608023772Wh
# 2023-07-04 11:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 11:30:00+00:00 net use -1142.8161608023772Wh
# charge 0.0 soc delta 0.0 to deal with -1142.8161608023772
# winter agile 2023-07-04 11:30:00+00:00 sun (61, 171), solar prod 1.395kWh*, usage 0.253* net_use_house -1.143 grid flow -1.143kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.21 total £753.13
# 2023-01-01 00:00:00+00:00 solar position (61, 186) solar production 341.6498883067046
# 2023-07-04 12:00:00+00:00 actual electrical usage 405.3060978538689Wh
# 2023-07-04 12:00:00+00:00 net electrical requirement 63.65620954716428Wh
# 2023-07-04 12:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 12:00:00+00:00 net use 63.65620954716428Wh
# 2023-07-04 12:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 12:00:00+00:00 sun (61, 186), solar prod 0.342kWh*, usage 0.405* net_use_house 0.064 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.064kWh -> 27.936kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £753.13
# 2023-01-01 00:00:00+00:00 solar position (60, 198) solar production 1831.79759839636
# 2023-07-04 12:30:00+00:00 actual electrical usage 363.97391860320664Wh
# 2023-07-04 12:30:00+00:00 net electrical requirement -1467.8236797931534Wh
# 2023-07-04 12:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 12:30:00+00:00 net use -1467.8236797931534Wh
# charge 70.72912171907066 soc delta 63.6562095471636 to deal with -1467.8236797931534
# winter agile 2023-07-04 12:30:00+00:00 sun (60, 198), solar prod 1.832kWh*, usage 0.364* net_use_house -1.468 grid flow -1.397kWh in@£0.2922 ex@£0.1822 battery flow 0.064kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.25 total £752.88
# 2023-01-01 00:00:00+00:00 solar position (58, 213) solar production 1197.1482277024975
# 2023-07-04 13:00:00+00:00 actual electrical usage 264.21782500168376Wh
# 2023-07-04 13:00:00+00:00 net electrical requirement -932.9304027008137Wh
# 2023-07-04 13:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 13:00:00+00:00 net use -932.9304027008137Wh
# charge 0.0 soc delta 0.0 to deal with -932.9304027008137
# winter agile 2023-07-04 13:00:00+00:00 sun (58, 213), solar prod 1.197kWh*, usage 0.264* net_use_house -0.933 grid flow -0.933kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.17 total £752.71
# 2023-01-01 00:00:00+00:00 solar position (55, 222) solar production 678.4191781701506
# 2023-07-04 13:30:00+00:00 actual electrical usage 234.65559790754494Wh
# 2023-07-04 13:30:00+00:00 net electrical requirement -443.7635802626057Wh
# 2023-07-04 13:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 13:30:00+00:00 net use -443.7635802626057Wh
# charge 0.0 soc delta 0.0 to deal with -443.7635802626057
# winter agile 2023-07-04 13:30:00+00:00 sun (55, 222), solar prod 0.678kWh*, usage 0.235* net_use_house -0.444 grid flow -0.444kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.08 total £752.63
# 2023-01-01 00:00:00+00:00 solar position (52, 234) solar production 1540.9820950831524
# 2023-07-04 14:00:00+00:00 actual electrical usage 245.4690118751307Wh
# 2023-07-04 14:00:00+00:00 net electrical requirement -1295.5130832080217Wh
# 2023-07-04 14:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 14:00:00+00:00 net use -1295.5130832080217Wh
# charge 0.0 soc delta 0.0 to deal with -1295.5130832080217
# winter agile 2023-07-04 14:00:00+00:00 sun (52, 234), solar prod 1.541kWh*, usage 0.245* net_use_house -1.296 grid flow -1.296kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.24 total £752.39
# 2023-01-01 00:00:00+00:00 solar position (48, 243) solar production 437.2623917995532
# 2023-07-04 14:30:00+00:00 actual electrical usage 362.4940605426656Wh
# 2023-07-04 14:30:00+00:00 net electrical requirement -74.76833125688762Wh
# 2023-07-04 14:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 14:30:00+00:00 net use -74.76833125688762Wh
# charge 0.0 soc delta 0.0 to deal with -74.76833125688762
# winter agile 2023-07-04 14:30:00+00:00 sun (48, 243), solar prod 0.437kWh*, usage 0.362* net_use_house -0.075 grid flow -0.075kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.01 total £752.38
# 2023-01-01 00:00:00+00:00 solar position (44, 249) solar production 335.19757504556156
# 2023-07-04 15:00:00+00:00 actual electrical usage 296.2182600884602Wh
# 2023-07-04 15:00:00+00:00 net electrical requirement -38.97931495710134Wh
# 2023-07-04 15:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 15:00:00+00:00 net use -38.97931495710134Wh
# charge 0.0 soc delta 0.0 to deal with -38.97931495710134
# winter agile 2023-07-04 15:00:00+00:00 sun (44, 249), solar prod 0.335kWh*, usage 0.296* net_use_house -0.039 grid flow -0.039kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.01 total £752.37
# 2023-01-01 00:00:00+00:00 solar position (39, 258) solar production 654.9588198072006
# 2023-07-04 15:30:00+00:00 actual electrical usage 258.2313027391284Wh
# 2023-07-04 15:30:00+00:00 net electrical requirement -396.7275170680722Wh
# 2023-07-04 15:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 15:30:00+00:00 net use -396.7275170680722Wh
# charge 0.0 soc delta 0.0 to deal with -396.7275170680722
# winter agile 2023-07-04 15:30:00+00:00 sun (39, 258), solar prod 0.655kWh*, usage 0.258* net_use_house -0.397 grid flow -0.397kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.07 total £752.30
# 2023-01-01 00:00:00+00:00 solar position (35, 264) solar production 548.6178303614258
# 2023-07-04 16:00:00+00:00 actual electrical usage 353.5340023227122Wh
# 2023-07-04 16:00:00+00:00 net electrical requirement -195.08382803871365Wh
# 2023-07-04 16:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 16:00:00+00:00 net use -195.08382803871365Wh
# charge 0.0 soc delta 0.0 to deal with -195.08382803871365
# winter agile 2023-07-04 16:00:00+00:00 sun (35, 264), solar prod 0.549kWh*, usage 0.354* net_use_house -0.195 grid flow -0.195kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 23.860kWh battery_wear=£0.00 hh=£-0.06 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (30, 270) solar production 302.56662146852466
# 2023-07-04 16:30:00+00:00 actual electrical usage 365.36651686032616Wh
# 2023-07-04 16:30:00+00:00 net electrical requirement 62.7998953918015Wh
# 2023-07-04 16:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 16:30:00+00:00 net use 62.7998953918015Wh
# 2023-07-04 16:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 16:30:00+00:00 sun (30, 270), solar prod 0.303kWh*, usage 0.365* net_use_house 0.063 grid flow 0.000kWh in@£0.409 ex@£0.299 battery flow -0.063kWh -> 27.937kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (25, 276) solar production 135.16344569194126
# 2023-07-04 17:00:00+00:00 actual electrical usage 363.91415051427373Wh
# 2023-07-04 17:00:00+00:00 net electrical requirement 228.75070482233247Wh
# 2023-07-04 17:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 17:00:00+00:00 net use 228.75070482233247Wh
# 2023-07-04 17:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 17:00:00+00:00 sun (25, 276), solar prod 0.135kWh*, usage 0.364* net_use_house 0.229 grid flow 0.000kWh in@£0.409 ex@£0.299 battery flow -0.229kWh -> 27.708kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (21, 282) solar production 76.0991044643543
# 2023-07-04 17:30:00+00:00 actual electrical usage 353.3703050657249Wh
# 2023-07-04 17:30:00+00:00 net electrical requirement 277.2712006013706Wh
# 2023-07-04 17:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 17:30:00+00:00 net use 277.2712006013706Wh
# 2023-07-04 17:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 17:30:00+00:00 sun (21, 282), solar prod 0.076kWh*, usage 0.353* net_use_house 0.277 grid flow 0.000kWh in@£0.409 ex@£0.299 battery flow -0.277kWh -> 27.431kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (16, 285) solar production 87.89845832056785
# 2023-07-04 18:00:00+00:00 actual electrical usage 1617.1473734118474Wh
# 2023-07-04 18:00:00+00:00 net electrical requirement 1529.2489150912795Wh
# 2023-07-04 18:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 18:00:00+00:00 net use 1529.2489150912795Wh
# 2023-07-04 18:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 18:00:00+00:00 sun (16, 285), solar prod 0.088kWh*, usage 1.617* net_use_house 1.529 grid flow 0.000kWh in@£0.409 ex@£0.299 battery flow -1.529kWh -> 25.902kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (12, 291) solar production 22.31628441553799
# 2023-07-04 18:30:00+00:00 actual electrical usage 1176.9675336133866Wh
# 2023-07-04 18:30:00+00:00 net electrical requirement 1154.6512491978488Wh
# 2023-07-04 18:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-04 18:30:00+00:00 net use 1154.6512491978488Wh
# 2023-07-04 18:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 18:30:00+00:00 sun (12, 291), solar prod 0.022kWh*, usage 1.177* net_use_house 1.155 grid flow 0.000kWh in@£0.409 ex@£0.299 battery flow -1.155kWh -> 24.747kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (8, 297) solar production 5.836954428806699
# 2023-07-04 19:00:00+00:00 actual electrical usage 327.61053781728634Wh
# 2023-07-04 19:00:00+00:00 net electrical requirement 321.77358338847966Wh
# 2023-07-04 19:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 19:00:00+00:00 net use 321.77358338847966Wh
# 2023-07-04 19:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 19:00:00+00:00 sun (8, 297), solar prod 0.006kWh*, usage 0.328* net_use_house 0.322 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.322kWh -> 24.426kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (4, 303) solar production 6.9942287867659685
# 2023-07-04 19:30:00+00:00 actual electrical usage 755.9027231216431Wh
# 2023-07-04 19:30:00+00:00 net electrical requirement 748.9084943348772Wh
# 2023-07-04 19:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 19:30:00+00:00 net use 748.9084943348772Wh
# 2023-07-04 19:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 19:30:00+00:00 sun (4, 303), solar prod 0.007kWh*, usage 0.756* net_use_house 0.749 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.749kWh -> 23.677kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (0, 309) solar production 6.879178542272514
# 2023-07-04 20:00:00+00:00 actual electrical usage 579.2997181727968Wh
# 2023-07-04 20:00:00+00:00 net electrical requirement 572.4205396305243Wh
# 2023-07-04 20:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 20:00:00+00:00 net use 572.4205396305243Wh
# 2023-07-04 20:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 20:00:00+00:00 sun (0, 309), solar prod 0.007kWh*, usage 0.579* net_use_house 0.572 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.572kWh -> 23.104kWh min_bat 23.860kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-3, 315) solar production 0.0
# 2023-07-04 20:30:00+00:00 actual electrical usage 564.7385704233533Wh
# 2023-07-04 20:30:00+00:00 net electrical requirement 564.7385704233533Wh
# 2023-07-04 20:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 20:30:00+00:00 net use 564.7385704233533Wh
# 2023-07-04 20:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 20:30:00+00:00 sun (-3, 315), solar prod 0.000kWh*, usage 0.565* net_use_house 0.565 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.565kWh -> 22.539kWh min_bat 23.677kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-7, 321) solar production 0.0
# 2023-07-04 21:00:00+00:00 actual electrical usage 517.4501123417383Wh
# 2023-07-04 21:00:00+00:00 net electrical requirement 517.4501123417383Wh
# 2023-07-04 21:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 21:00:00+00:00 net use 517.4501123417383Wh
# 2023-07-04 21:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 21:00:00+00:00 sun (-7, 321), solar prod 0.000kWh*, usage 0.517* net_use_house 0.517 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.517kWh -> 22.022kWh min_bat 23.104kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-9, 327) solar production 0.0
# 2023-07-04 21:30:00+00:00 actual electrical usage 205.4672614886843Wh
# 2023-07-04 21:30:00+00:00 net electrical requirement 205.4672614886843Wh
# 2023-07-04 21:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 21:30:00+00:00 net use 205.4672614886843Wh
# 2023-07-04 21:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 21:30:00+00:00 sun (-9, 327), solar prod 0.000kWh*, usage 0.205* net_use_house 0.205 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.205kWh -> 21.817kWh min_bat 22.539kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-12, 333) solar production 0.0
# 2023-07-04 22:00:00+00:00 actual electrical usage 192.58369758540192Wh
# 2023-07-04 22:00:00+00:00 net electrical requirement 192.58369758540192Wh
# 2023-07-04 22:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 22:00:00+00:00 net use 192.58369758540192Wh
# 2023-07-04 22:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 22:00:00+00:00 sun (-12, 333), solar prod 0.000kWh*, usage 0.193* net_use_house 0.193 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.193kWh -> 21.624kWh min_bat 22.022kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-13, 342) solar production 0.0
# 2023-07-04 22:30:00+00:00 actual electrical usage 179.54581835951126Wh
# 2023-07-04 22:30:00+00:00 net electrical requirement 179.54581835951126Wh
# 2023-07-04 22:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 22:30:00+00:00 net use 179.54581835951126Wh
# 2023-07-04 22:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 22:30:00+00:00 sun (-13, 342), solar prod 0.000kWh*, usage 0.180* net_use_house 0.180 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.180kWh -> 21.444kWh min_bat 21.817kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-15, 348) solar production 0.0
# 2023-07-04 23:00:00+00:00 actual electrical usage 169.6649568798898Wh
# 2023-07-04 23:00:00+00:00 net electrical requirement 169.6649568798898Wh
# 2023-07-04 23:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 23:00:00+00:00 net use 169.6649568798898Wh
# 2023-07-04 23:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 23:00:00+00:00 sun (-15, 348), solar prod 0.000kWh*, usage 0.170* net_use_house 0.170 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.170kWh -> 21.275kWh min_bat 21.624kWh battery_wear=£0.00 hh=£0.00 total £752.24
# 2023-01-01 00:00:00+00:00 solar position (-15, 354) solar production 0.0
# 2023-07-04 23:30:00+00:00 actual electrical usage 185.122254142542Wh
# 2023-07-04 23:30:00+00:00 net electrical requirement 185.122254142542Wh
# 2023-07-04 23:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-04 23:30:00+00:00 net use 185.122254142542Wh
# 2023-07-04 23:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-04 23:30:00+00:00 sun (-15, 354), solar prod 0.000kWh*, usage 0.185* net_use_house 0.185 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.185kWh -> 21.090kWh min_bat 21.444kWh battery_wear=£0.00 hh=£0.00 total £752.24
# day 185
# charge slots [(12.9654, '03:30'), (13.803300000000002, '02:30'), (14.35455, '04:00'), (14.927850000000001, '01:30'), (15.556275000000001, '02:00')]
# 2023-01-01 00:00:00+00:00 solar position (-15, 3) solar production 0.0
# 2023-07-05 00:00:00+00:00 actual electrical usage 181.00822350184123Wh
# 2023-07-05 00:00:00+00:00 net electrical requirement 181.00822350184123Wh
# 2023-07-05 00:00:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 00:00:00+00:00 gas use 0.0kWh, cost £$0.27
# 2023-07-05 00:00:00+00:00 net use 181.00822350184123Wh
# 2023-07-05 00:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 00:00:00+00:00 sun (-15, 3), solar prod 0.000kWh*, usage 0.181* net_use_house 0.181 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.181kWh -> 20.909kWh min_bat 21.090kWh battery_wear=£0.00 hh=£0.69 total £752.94
# 2023-01-01 00:00:00+00:00 solar position (-15, 9) solar production 0.0
# 2023-07-05 00:30:00+00:00 actual electrical usage 165.6488489452028Wh
# 2023-07-05 00:30:00+00:00 net electrical requirement 165.6488489452028Wh
# 2023-07-05 00:30:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 00:30:00+00:00 net use 165.6488489452028Wh
# 2023-07-05 00:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 00:30:00+00:00 sun (-15, 9), solar prod 0.000kWh*, usage 0.166* net_use_house 0.166 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.166kWh -> 20.743kWh min_bat 21.090kWh battery_wear=£0.00 hh=£0.00 total £752.94
# 2023-01-01 00:00:00+00:00 solar position (-14, 18) solar production 0.0
# 2023-07-05 01:00:00+00:00 actual electrical usage 185.60254518026596Wh
# 2023-07-05 01:00:00+00:00 net electrical requirement 185.60254518026596Wh
# 2023-07-05 01:00:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 01:00:00+00:00 net use 185.60254518026596Wh
# 2023-07-05 01:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 01:00:00+00:00 sun (-14, 18), solar prod 0.000kWh*, usage 0.186* net_use_house 0.186 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.186kWh -> 20.557kWh min_bat 20.909kWh battery_wear=£0.00 hh=£0.00 total £752.94
# 2023-01-01 00:00:00+00:00 solar position (-12, 24) solar production 0.0
# 2023-07-05 01:30:00+00:00 actual electrical usage 183.6210267680032Wh
# 2023-07-05 01:30:00+00:00 net electrical requirement 183.6210267680032Wh
# 2023-07-05 01:30:00+00:00 price structure {'start': 0, 'end': 2, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 01:30:00+00:00 net use 183.6210267680032Wh
# 2023-07-05 01:30:00+00:00 taking $0.0Wh from grid
# grid charge 5183.6210267680035 add 4665.258924091203 soc delta was -183.6210267680032 now 4481.6378973231995
# winter agile 2023-07-05 01:30:00+00:00 sun (-12, 24), solar prod 0.000kWh*, usage 0.184* net_use_house 0.184 grid flow 5.184kWh in@£0.2922 ex@£0.1822 battery flow 4.482kWh -> 25.039kWh min_bat 20.743kWh battery_wear=£0.00 hh=£1.51 total £754.45
# 2023-01-01 00:00:00+00:00 solar position (-10, 30) solar production 0.0
# 2023-07-05 02:00:00+00:00 actual electrical usage 164.5985880588663Wh
# 2023-07-05 02:00:00+00:00 net electrical requirement 164.5985880588663Wh
# 2023-07-05 02:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 02:00:00+00:00 net use 164.5985880588663Wh
# 2023-07-05 02:00:00+00:00 taking $0.0Wh from grid
# grid charge 3454.6196702630427 add 3109.1577032367386 soc delta was -164.5985880588663 now 2944.559115177872
# winter agile 2023-07-05 02:00:00+00:00 sun (-10, 30), solar prod 0.000kWh*, usage 0.165* net_use_house 0.165 grid flow 3.455kWh in@£0.1753 ex@£0.0653 battery flow 2.945kWh -> 27.984kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.61 total £755.06
# 2023-01-01 00:00:00+00:00 solar position (-8, 36) solar production 0.0
# 2023-07-05 02:30:00+00:00 actual electrical usage 170.79481998092828Wh
# 2023-07-05 02:30:00+00:00 net electrical requirement 170.79481998092828Wh
# 2023-07-05 02:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 02:30:00+00:00 net use 170.79481998092828Wh
# 2023-07-05 02:30:00+00:00 taking $0.0Wh from grid
# grid charge 189.08355198746943 add 170.1751967887225 soc delta was -170.79481998092828 now -0.6196231922057791
# winter agile 2023-07-05 02:30:00+00:00 sun (-8, 36), solar prod 0.000kWh*, usage 0.171* net_use_house 0.171 grid flow 0.189kWh in@£0.1753 ex@£0.0653 battery flow -0.001kWh -> 27.983kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.03 total £755.09
# 2023-01-01 00:00:00+00:00 solar position (-5, 42) solar production 0.0
# 2023-07-05 03:00:00+00:00 actual electrical usage 176.039933071887Wh
# 2023-07-05 03:00:00+00:00 net electrical requirement 176.039933071887Wh
# 2023-07-05 03:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 03:00:00+00:00 net use 176.039933071887Wh
# 2023-07-05 03:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 03:00:00+00:00 sun (-5, 42), solar prod 0.000kWh*, usage 0.176* net_use_house 0.176 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.176kWh -> 27.807kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.09
# 2023-01-01 00:00:00+00:00 solar position (-1, 48) solar production 0.0
# 2023-07-05 03:30:00+00:00 actual electrical usage 162.83996201267948Wh
# 2023-07-05 03:30:00+00:00 net electrical requirement 162.83996201267948Wh
# 2023-07-05 03:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 03:30:00+00:00 net use 162.83996201267948Wh
# 2023-07-05 03:30:00+00:00 taking $0.0Wh from grid
# grid charge 377.41708986821004 add 339.67538088138906 soc delta was -162.83996201267948 now 176.83541886870958
# winter agile 2023-07-05 03:30:00+00:00 sun (-1, 48), solar prod 0.000kWh*, usage 0.163* net_use_house 0.163 grid flow 0.377kWh in@£0.1753 ex@£0.0653 battery flow 0.177kWh -> 27.984kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.07 total £755.16
# 2023-01-01 00:00:00+00:00 solar position (3, 54) solar production 6.41239418625306
# 2023-07-05 04:00:00+00:00 actual electrical usage 174.74422669355897Wh
# 2023-07-05 04:00:00+00:00 net electrical requirement 168.3318325073059Wh
# 2023-07-05 04:00:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 04:00:00+00:00 net use 168.3318325073059Wh
# 2023-07-05 04:00:00+00:00 taking $0.0Wh from grid
# grid charge 186.42516161982755 add 167.7826454578448 soc delta was -168.3318325073059 now -0.5491870494610964
# winter agile 2023-07-05 04:00:00+00:00 sun (3, 54), solar prod 0.006kWh*, usage 0.175* net_use_house 0.168 grid flow 0.186kWh in@£0.1753 ex@£0.0653 battery flow -0.001kWh -> 27.983kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.03 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (6, 60) solar production 53.61784400883123
# 2023-07-05 04:30:00+00:00 actual electrical usage 825.53334281746Wh
# 2023-07-05 04:30:00+00:00 net electrical requirement 771.9154988086289Wh
# 2023-07-05 04:30:00+00:00 price structure {'start': 2, 'end': 5, 'import': 0.1753, 'export': 0.0653}
# 2023-07-05 04:30:00+00:00 net use 771.9154988086289Wh
# 2023-07-05 04:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 04:30:00+00:00 sun (6, 60), solar prod 0.054kWh*, usage 0.826* net_use_house 0.772 grid flow 0.000kWh in@£0.1753 ex@£0.0653 battery flow -0.772kWh -> 27.211kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (10, 66) solar production 110.31854229237207
# 2023-07-05 05:00:00+00:00 actual electrical usage 1603.0389258736657Wh
# 2023-07-05 05:00:00+00:00 net electrical requirement 1492.7203835812936Wh
# 2023-07-05 05:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 05:00:00+00:00 net use 1492.7203835812936Wh
# 2023-07-05 05:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 05:00:00+00:00 sun (10, 66), solar prod 0.110kWh*, usage 1.603* net_use_house 1.493 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -1.493kWh -> 25.719kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (15, 72) solar production 163.9485175310323
# 2023-07-05 05:30:00+00:00 actual electrical usage 620.9350140845639Wh
# 2023-07-05 05:30:00+00:00 net electrical requirement 456.98649655353165Wh
# 2023-07-05 05:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 05:30:00+00:00 net use 456.98649655353165Wh
# 2023-07-05 05:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-05 05:30:00+00:00 sun (15, 72), solar prod 0.164kWh*, usage 0.621* net_use_house 0.457 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.457kWh -> 25.262kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (19, 78) solar production 229.7369094916336
# 2023-07-05 06:00:00+00:00 actual electrical usage 178.85326294570132Wh
# 2023-07-05 06:00:00+00:00 net electrical requirement -50.883646545932294Wh
# 2023-07-05 06:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 06:00:00+00:00 net use -50.883646545932294Wh
# charge 50.883646545932294 soc delta 45.795281891339066 to deal with -50.883646545932294
# winter agile 2023-07-05 06:00:00+00:00 sun (19, 78), solar prod 0.230kWh*, usage 0.179* net_use_house -0.051 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.046kWh -> 25.307kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (24, 84) solar production 762.0859069608201
# 2023-07-05 06:30:00+00:00 actual electrical usage 162.20532246548618Wh
# 2023-07-05 06:30:00+00:00 net electrical requirement -599.880584495334Wh
# 2023-07-05 06:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 06:30:00+00:00 net use -599.880584495334Wh
# charge 599.880584495334 soc delta 539.8925260458007 to deal with -599.880584495334
# winter agile 2023-07-05 06:30:00+00:00 sun (24, 84), solar prod 0.762kWh*, usage 0.162* net_use_house -0.600 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.540kWh -> 25.847kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (28, 90) solar production 770.503824308742
# 2023-07-05 07:00:00+00:00 actual electrical usage 199.69733874880032Wh
# 2023-07-05 07:00:00+00:00 net electrical requirement -570.8064855599416Wh
# 2023-07-05 07:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 07:00:00+00:00 net use -570.8064855599416Wh
# charge 570.8064855599416 soc delta 513.7258370039475 to deal with -570.8064855599416
# winter agile 2023-07-05 07:00:00+00:00 sun (28, 90), solar prod 0.771kWh*, usage 0.200* net_use_house -0.571 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.514kWh -> 26.361kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (33, 96) solar production 902.147350303328
# 2023-07-05 07:30:00+00:00 actual electrical usage 280.06783611523593Wh
# 2023-07-05 07:30:00+00:00 net electrical requirement -622.0795141880922Wh
# 2023-07-05 07:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 07:30:00+00:00 net use -622.0795141880922Wh
# charge 622.0795141880922 soc delta 559.871562769283 to deal with -622.0795141880922
# winter agile 2023-07-05 07:30:00+00:00 sun (33, 96), solar prod 0.902kWh*, usage 0.280* net_use_house -0.622 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.560kWh -> 26.921kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (38, 102) solar production 1392.443975101003
# 2023-07-05 08:00:00+00:00 actual electrical usage 235.1280706296022Wh
# 2023-07-05 08:00:00+00:00 net electrical requirement -1157.3159044714007Wh
# 2023-07-05 08:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 08:00:00+00:00 net use -1157.3159044714007Wh
# charge 1157.3159044714007 soc delta 1041.5843140242607 to deal with -1157.3159044714007
# winter agile 2023-07-05 08:00:00+00:00 sun (38, 102), solar prod 1.392kWh*, usage 0.235* net_use_house -1.157 grid flow -0.000kWh in@£0.2922 ex@£0.1822 battery flow 1.042kWh -> 27.962kWh min_bat 20.557kWh battery_wear=£0.00 hh=£0.00 total £755.19
# 2023-01-01 00:00:00+00:00 solar position (42, 108) solar production 2131.010276245288
# 2023-07-05 08:30:00+00:00 actual electrical usage 209.81159326043323Wh
# 2023-07-05 08:30:00+00:00 net electrical requirement -1921.1986829848547Wh
# 2023-07-05 08:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 08:30:00+00:00 net use -1921.1986829848547Wh
# charge 41.76226717727938 soc delta 37.58604045955144 to deal with -1921.1986829848547
# winter agile 2023-07-05 08:30:00+00:00 sun (42, 108), solar prod 2.131kWh*, usage 0.210* net_use_house -1.921 grid flow -1.879kWh in@£0.2922 ex@£0.1822 battery flow 0.038kWh -> 28.000kWh min_bat 20.557kWh battery_wear=£0.00 hh=£-0.34 total £754.85
# 2023-01-01 00:00:00+00:00 solar position (46, 114) solar production 2041.0937027554446
# 2023-07-05 09:00:00+00:00 actual electrical usage 277.2352738887413Wh
# 2023-07-05 09:00:00+00:00 net electrical requirement -1763.8584288667034Wh
# 2023-07-05 09:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 09:00:00+00:00 net use -1763.8584288667034Wh
# charge 0.0 soc delta 0.0 to deal with -1763.8584288667034
# winter agile 2023-07-05 09:00:00+00:00 sun (46, 114), solar prod 2.041kWh*, usage 0.277* net_use_house -1.764 grid flow -1.764kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 20.557kWh battery_wear=£0.00 hh=£-0.32 total £754.52
# 2023-01-01 00:00:00+00:00 solar position (50, 123) solar production 3027.3476181335454
# 2023-07-05 09:30:00+00:00 actual electrical usage 224.9597980016949Wh
# 2023-07-05 09:30:00+00:00 net electrical requirement -2802.3878201318507Wh
# 2023-07-05 09:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-05 09:30:00+00:00 net use -2802.3878201318507Wh
# charge 0.0 soc delta 0.0 to deal with -2802.3878201318507
# ...
# 2023-01-01 00:00:00+00:00 solar position (59, 198) solar production 2022.9566187984863
# 2023-07-13 12:30:00+00:00 actual electrical usage 160.79057167229195Wh
# 2023-07-13 12:30:00+00:00 net electrical requirement -1862.1660471261944Wh
# 2023-07-13 12:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 12:30:00+00:00 net use -1862.1660471261944Wh
# charge 0.0 soc delta 0.0 to deal with -1862.1660471261944
# grid charge 0.0 add 0.0 soc delta was 0.0 now 0.0
# winter agile 2023-07-13 12:30:00+00:00 sun (59, 198), solar prod 2.023kWh*, usage 0.161* net_use_house -1.862 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.34 total £704.12
# 2023-01-01 00:00:00+00:00 solar position (57, 210) solar production 1963.4757402195248
# 2023-07-13 13:00:00+00:00 actual electrical usage 140.0393595377605Wh
# 2023-07-13 13:00:00+00:00 net electrical requirement -1823.4363806817644Wh
# 2023-07-13 13:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 13:00:00+00:00 net use -1823.4363806817644Wh
# charge 0.0 soc delta 0.0 to deal with -1823.4363806817644
# winter agile 2023-07-13 13:00:00+00:00 sun (57, 210), solar prod 1.963kWh*, usage 0.140* net_use_house -1.823 grid flow -1.823kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.33 total £703.78
# 2023-01-01 00:00:00+00:00 solar position (54, 222) solar production 2879.6135631193497
# 2023-07-13 13:30:00+00:00 actual electrical usage 163.35904933885598Wh
# 2023-07-13 13:30:00+00:00 net electrical requirement -2716.2545137804937Wh
# 2023-07-13 13:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 13:30:00+00:00 net use -2716.2545137804937Wh
# charge 0.0 soc delta 0.0 to deal with -2716.2545137804937
# winter agile 2023-07-13 13:30:00+00:00 sun (54, 222), solar prod 2.880kWh*, usage 0.163* net_use_house -2.716 grid flow -2.716kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.49 total £703.29
# 2023-01-01 00:00:00+00:00 solar position (51, 231) solar production 4483.884372684616
# 2023-07-13 14:00:00+00:00 actual electrical usage 156.7449960494863Wh
# 2023-07-13 14:00:00+00:00 net electrical requirement -4327.13937663513Wh
# 2023-07-13 14:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 14:00:00+00:00 net use -4327.13937663513Wh
# charge 0.0 soc delta 0.0 to deal with -4327.13937663513
# grid charge 0.0 add 0.0 soc delta was 0.0 now 0.0
# winter agile 2023-07-13 14:00:00+00:00 sun (51, 231), solar prod 4.484kWh*, usage 0.157* net_use_house -4.327 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.79 total £702.50
# 2023-01-01 00:00:00+00:00 solar position (47, 240) solar production 3628.5521204707197
# 2023-07-13 14:30:00+00:00 actual electrical usage 145.0475187860783Wh
# 2023-07-13 14:30:00+00:00 net electrical requirement -3483.5046016846413Wh
# 2023-07-13 14:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 14:30:00+00:00 net use -3483.5046016846413Wh
# charge 0.0 soc delta 0.0 to deal with -3483.5046016846413
# winter agile 2023-07-13 14:30:00+00:00 sun (47, 240), solar prod 3.629kWh*, usage 0.145* net_use_house -3.484 grid flow -3.484kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.63 total £701.87
# 2023-01-01 00:00:00+00:00 solar position (43, 249) solar production 3507.50146474429
# 2023-07-13 15:00:00+00:00 actual electrical usage 145.68230826991723Wh
# 2023-07-13 15:00:00+00:00 net electrical requirement -3361.819156474373Wh
# 2023-07-13 15:00:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 15:00:00+00:00 net use -3361.819156474373Wh
# charge 0.0 soc delta 0.0 to deal with -3361.819156474373
# winter agile 2023-07-13 15:00:00+00:00 sun (43, 249), solar prod 3.508kWh*, usage 0.146* net_use_house -3.362 grid flow -3.362kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.61 total £701.25
# 2023-01-01 00:00:00+00:00 solar position (39, 255) solar production 2141.157631818862
# 2023-07-13 15:30:00+00:00 actual electrical usage 159.6545744051879Wh
# 2023-07-13 15:30:00+00:00 net electrical requirement -1981.5030574136738Wh
# 2023-07-13 15:30:00+00:00 price structure {'start': 5, 'end': 16, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 15:30:00+00:00 net use -1981.5030574136738Wh
# charge 0.0 soc delta 0.0 to deal with -1981.5030574136738
# winter agile 2023-07-13 15:30:00+00:00 sun (39, 255), solar prod 2.141kWh*, usage 0.160* net_use_house -1.982 grid flow -1.982kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.36 total £700.89
# 2023-01-01 00:00:00+00:00 solar position (34, 261) solar production 1612.495918847615
# 2023-07-13 16:00:00+00:00 actual electrical usage 160.41159524342106Wh
# 2023-07-13 16:00:00+00:00 net electrical requirement -1452.084323604194Wh
# 2023-07-13 16:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 16:00:00+00:00 net use -1452.084323604194Wh
# charge 0.0 soc delta 0.0 to deal with -1452.084323604194
# winter agile 2023-07-13 16:00:00+00:00 sun (34, 261), solar prod 1.612kWh*, usage 0.160* net_use_house -1.452 grid flow -1.452kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.43 total £700.46
# 2023-01-01 00:00:00+00:00 solar position (29, 267) solar production 1645.4555563664603
# 2023-07-13 16:30:00+00:00 actual electrical usage 140.47644393415675Wh
# 2023-07-13 16:30:00+00:00 net electrical requirement -1504.9791124323035Wh
# 2023-07-13 16:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 16:30:00+00:00 net use -1504.9791124323035Wh
# charge 0.0 soc delta 0.0 to deal with -1504.9791124323035
# winter agile 2023-07-13 16:30:00+00:00 sun (29, 267), solar prod 1.645kWh*, usage 0.140* net_use_house -1.505 grid flow -1.505kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.45 total £700.01
# 2023-01-01 00:00:00+00:00 solar position (25, 273) solar production 1229.7700350578098
# 2023-07-13 17:00:00+00:00 actual electrical usage 161.69111712225555Wh
# 2023-07-13 17:00:00+00:00 net electrical requirement -1068.0789179355543Wh
# 2023-07-13 17:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 17:00:00+00:00 net use -1068.0789179355543Wh
# charge 0.0 soc delta 0.0 to deal with -1068.0789179355543
# winter agile 2023-07-13 17:00:00+00:00 sun (25, 273), solar prod 1.230kWh*, usage 0.162* net_use_house -1.068 grid flow -1.068kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.32 total £699.69
# 2023-01-01 00:00:00+00:00 solar position (20, 279) solar production 797.8756512229381
# 2023-07-13 17:30:00+00:00 actual electrical usage 161.66465162956854Wh
# 2023-07-13 17:30:00+00:00 net electrical requirement -636.2109995933696Wh
# 2023-07-13 17:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 17:30:00+00:00 net use -636.2109995933696Wh
# charge 0.0 soc delta 0.0 to deal with -636.2109995933696
# winter agile 2023-07-13 17:30:00+00:00 sun (20, 279), solar prod 0.798kWh*, usage 0.162* net_use_house -0.636 grid flow -0.636kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.19 total £699.50
# 2023-01-01 00:00:00+00:00 solar position (16, 285) solar production 669.6110293619714
# 2023-07-13 18:00:00+00:00 actual electrical usage 150.6807046649099Wh
# 2023-07-13 18:00:00+00:00 net electrical requirement -518.9303246970615Wh
# 2023-07-13 18:00:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 18:00:00+00:00 net use -518.9303246970615Wh
# charge 0.0 soc delta 0.0 to deal with -518.9303246970615
# winter agile 2023-07-13 18:00:00+00:00 sun (16, 285), solar prod 0.670kWh*, usage 0.151* net_use_house -0.519 grid flow -0.519kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.16 total £699.34
# 2023-01-01 00:00:00+00:00 solar position (11, 291) solar production 314.4763210994508
# 2023-07-13 18:30:00+00:00 actual electrical usage 152.04904374622166Wh
# 2023-07-13 18:30:00+00:00 net electrical requirement -162.42727735322913Wh
# 2023-07-13 18:30:00+00:00 price structure {'start': 16, 'end': 19, 'import': 0.409, 'export': 0.299}
# 2023-07-13 18:30:00+00:00 net use -162.42727735322913Wh
# charge 0.0 soc delta 0.0 to deal with -162.42727735322913
# winter agile 2023-07-13 18:30:00+00:00 sun (11, 291), solar prod 0.314kWh*, usage 0.152* net_use_house -0.162 grid flow -0.162kWh in@£0.409 ex@£0.299 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.05 total £699.30
# 2023-01-01 00:00:00+00:00 solar position (7, 297) solar production 239.73238913434201
# 2023-07-13 19:00:00+00:00 actual electrical usage 160.78636994635926Wh
# 2023-07-13 19:00:00+00:00 net electrical requirement -78.94601918798276Wh
# 2023-07-13 19:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 19:00:00+00:00 net use -78.94601918798276Wh
# charge 0.0 soc delta 0.0 to deal with -78.94601918798276
# winter agile 2023-07-13 19:00:00+00:00 sun (7, 297), solar prod 0.240kWh*, usage 0.161* net_use_house -0.079 grid flow -0.079kWh in@£0.2922 ex@£0.1822 battery flow 0.000kWh -> 28.000kWh min_bat 25.536kWh battery_wear=£0.00 hh=£-0.01 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (3, 303) solar production 48.41858600186407
# 2023-07-13 19:30:00+00:00 actual electrical usage 161.41122206978173Wh
# 2023-07-13 19:30:00+00:00 net electrical requirement 112.99263606791766Wh
# 2023-07-13 19:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 19:30:00+00:00 net use 112.99263606791766Wh
# 2023-07-13 19:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 19:30:00+00:00 sun (3, 303), solar prod 0.048kWh*, usage 0.161* net_use_house 0.113 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.113kWh -> 27.887kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (0, 309) solar production 8.07958337392786
# 2023-07-13 20:00:00+00:00 actual electrical usage 198.09932039011088Wh
# 2023-07-13 20:00:00+00:00 net electrical requirement 190.019737016183Wh
# 2023-07-13 20:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 20:00:00+00:00 net use 190.019737016183Wh
# 2023-07-13 20:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 20:00:00+00:00 sun (0, 309), solar prod 0.008kWh*, usage 0.198* net_use_house 0.190 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.190kWh -> 27.697kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-4, 315) solar production 0.0
# 2023-07-13 20:30:00+00:00 actual electrical usage 348.98249590643513Wh
# 2023-07-13 20:30:00+00:00 net electrical requirement 348.98249590643513Wh
# 2023-07-13 20:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 20:30:00+00:00 net use 348.98249590643513Wh
# 2023-07-13 20:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 20:30:00+00:00 sun (-4, 315), solar prod 0.000kWh*, usage 0.349* net_use_house 0.349 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.349kWh -> 27.348kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-7, 321) solar production 0.0
# 2023-07-13 21:00:00+00:00 actual electrical usage 385.8746938509819Wh
# 2023-07-13 21:00:00+00:00 net electrical requirement 385.8746938509819Wh
# 2023-07-13 21:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 21:00:00+00:00 net use 385.8746938509819Wh
# 2023-07-13 21:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 21:00:00+00:00 sun (-7, 321), solar prod 0.000kWh*, usage 0.386* net_use_house 0.386 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.386kWh -> 26.962kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-10, 327) solar production 0.0
# 2023-07-13 21:30:00+00:00 actual electrical usage 384.20327872572267Wh
# 2023-07-13 21:30:00+00:00 net electrical requirement 384.20327872572267Wh
# 2023-07-13 21:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 21:30:00+00:00 net use 384.20327872572267Wh
# 2023-07-13 21:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 21:30:00+00:00 sun (-10, 327), solar prod 0.000kWh*, usage 0.384* net_use_house 0.384 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.384kWh -> 26.578kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-12, 333) solar production 0.0
# 2023-07-13 22:00:00+00:00 actual electrical usage 346.6218175855176Wh
# 2023-07-13 22:00:00+00:00 net electrical requirement 346.6218175855176Wh
# 2023-07-13 22:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 22:00:00+00:00 net use 346.6218175855176Wh
# 2023-07-13 22:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 22:00:00+00:00 sun (-12, 333), solar prod 0.000kWh*, usage 0.347* net_use_house 0.347 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.347kWh -> 26.231kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-14, 339) solar production 0.0
# 2023-07-13 22:30:00+00:00 actual electrical usage 348.1554139707281Wh
# 2023-07-13 22:30:00+00:00 net electrical requirement 348.1554139707281Wh
# 2023-07-13 22:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 22:30:00+00:00 net use 348.1554139707281Wh
# 2023-07-13 22:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 22:30:00+00:00 sun (-14, 339), solar prod 0.000kWh*, usage 0.348* net_use_house 0.348 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.348kWh -> 25.883kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-16, 348) solar production 0.0
# 2023-07-13 23:00:00+00:00 actual electrical usage 340.445324335427Wh
# 2023-07-13 23:00:00+00:00 net electrical requirement 340.445324335427Wh
# 2023-07-13 23:00:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 23:00:00+00:00 net use 340.445324335427Wh
# 2023-07-13 23:00:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 23:00:00+00:00 sun (-16, 348), solar prod 0.000kWh*, usage 0.340* net_use_house 0.340 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.340kWh -> 25.543kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# 2023-01-01 00:00:00+00:00 solar position (-16, 354) solar production 0.0
# 2023-07-13 23:30:00+00:00 actual electrical usage 229.40061872854997Wh
# 2023-07-13 23:30:00+00:00 net electrical requirement 229.40061872854997Wh
# 2023-07-13 23:30:00+00:00 price structure {'start': 19, 'end': 24, 'import': 0.2922, 'export': 0.1822}
# 2023-07-13 23:30:00+00:00 net use 229.40061872854997Wh
# 2023-07-13 23:30:00+00:00 taking $0.0Wh from grid
# winter agile 2023-07-13 23:30:00+00:00 sun (-16, 354), solar prod 0.000kWh*, usage 0.229* net_use_house 0.229 grid flow 0.000kWh in@£0.2922 ex@£0.1822 battery flow -0.229kWh -> 25.313kWh min_bat 25.536kWh battery_wear=£0.00 hh=£0.00 total £699.28
# day 194

# %%
agile_results = simulate_tariff(name='agile',         
        costs= [
            {
                'start': 0,
                'end': 24,
                'import': 'agile',
                'export': 'agile',
            },
        ],
        winter_agile_import=True,
        grid_charge = True,
        agile_charge=True,
        battery = True, solar=True,
        color=  'blue', verbose=True,
        saving_sessions_discharge=True)
agile_results

# %%
def plot(results_list):
    f, (ax1, ax2, ax3, ax4) = matplotlib.pyplot.subplots(4, 1, sharex=True)
    f.set_figwidth(18)
    f.set_figheight(18)

    for r in results_list:        
        ax1.plot(r['days'], r['cost_series'], color=r['color'], label=r['name'])
        ax1.set_ylabel('cumulative cost, £')
        ax2.plot(r['days'], r['soc_daily_lows'],  color=r['color'], label=r['name'])
        ax2.set_ylabel('battery daily low %')

        if [x for x in r['kwh_days'] if x > 0] :        
            ax3.plot(r['days'], r['kwh_days'])
        ax3.set_ylabel('solar production, Wh')
        ax4.plot(r['months'], r['month_cost'], color=r['color'], label=r['name'])
        ax4.set_ylabel('monthly cost, £')
        print('plan', r['name'], r['cost_series'][-1])

    ax1.legend()
    ax2.legend()
    ax4.legend()

winter_agile_result['color'] = 'pink'
plot([old_results, current_results, agile_results, winter_agile_result, discharge_results])
